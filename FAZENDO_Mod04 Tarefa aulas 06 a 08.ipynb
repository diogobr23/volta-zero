# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

r = requests.get(url)

# %%
# verificar o status de conexão
r.status_code
# Out:
# 200

# %%
# criando o dataframe
data_json = r.json()

# imprimindo o dicionário 'items'
print(data_json['items'])
# Out:
# [{'id_pleito': 10642, 'tipo_interessado': 'Município', 'interessado': 'Araricá', 'cod_ibge': 4300877, 'uf': 'RS', 'num_pvl': None, 'status': 'Arquivado por decurso de prazo', 'num_processo': '17944.001250/2011-71', 'data_protocolo': '2012-01-20T02:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PAC 2 - Pró-Transporte - Pavimentação e Qualificação de Vias', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 3660000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '14/02/2012'}, {'id_pleito': 11562, 'tipo_interessado': 'Estado', 'interessado': 'Rio Grande do Sul', 'cod_ibge': 43, 'uf': 'RS', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001477/2012-05', 'data_protocolo': '2014-06-06T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Interamericano de Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 50000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '01/07/2014'}, {'id_pleito': 11571, 'tipo_interessado': 'Estado', 'interessado': 'Minas Gerais', 'cod_ibge': 31, 'uf': 'MG', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001479/2009-91', 'data_protocolo': '2010-03-26T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 461000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '01/04/2010'}, {'id_pleito': 13182, 'tipo_interessado': 'Município', 'interessado': 'São Domingos', 'cod_ibge': 4216107, 'uf': 'SC', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.001947/2014-94', 'data_protocolo': '2015-01-15T02:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PAC 2 - Pró-Transporte - Pavimentação e Qualificação de Vias', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 1000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '28/01/2015'}, {'id_pleito': 13861, 'tipo_interessado': 'Município', 'interessado': 'Monte Castelo', 'cod_ibge': 4211108, 'uf': 'SC', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '19406.000004/2003-12', 'data_protocolo': '2003-01-22T02:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agência de Fomento do Estado de Santa Catarina S/A', 'moeda': 'Real', 'valor': 300000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '20/02/2003'}, {'id_pleito': 20450, 'tipo_interessado': 'Município', 'interessado': 'Itapagipe', 'cod_ibge': 3133402, 'uf': 'MG', 'num_pvl': '00000.000000/2019-67', 'status': 'Deferido', 'num_processo': '17944.001080/2015-58', 'data_protocolo': '2015-12-15T02:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco de Desenvolvimento de Minas Gerais S/A', 'moeda': 'Real', 'valor': 1000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '23/12/2015'}, {'id_pleito': 22310, 'tipo_interessado': 'Município', 'interessado': 'Santa Cecília', 'cod_ibge': 4215505, 'uf': 'SC', 'num_pvl': '00000.000000/2023-50', 'status': 'Deferido', 'num_processo': '17944.000506/2016-37', 'data_protocolo': '2016-09-01T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Regional de Desenvolvimento do Extremo Sul', 'moeda': 'Real', 'valor': 2000000, 'pvl ...

# %%
# criando o dataframe
data_br = pd.DataFrame(data_json['items'])
data_br
# Out:
#       id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 0         10642        Município               Araricá   4300877  RS
# 1         11562           Estado     Rio Grande do Sul        43  RS
# 2         11571           Estado          Minas Gerais        31  MG
# 3         13182        Município          São Domingos   4216107  SC
# 4         13861        Município         Monte Castelo   4211108  SC
# ...         ...              ...                   ...       ...  ..
# 4995      45183        Município               Virmond   4128658  PR
# 4996      45253        Município             Guapirama   4109005  PR
# 4997      46392        Município          Rio do Prado   3155108  MG
# 4998      46431        Município  São José dos Pinhais   4125506  PR
# 4999      53709        Município              Salvador   2927408  BA
#
#                    num_pvl                                             status  \
# 0                     None                     Arquivado por decurso de prazo
# 1                     None  Encaminhado à PGFN com manifestação técnica fa...
# 2                     None  Encaminhado à PGFN com manifestação técnica fa...
# 3                     None                                           Deferido
# 4                     None                                           Deferido
# ...                    ...                                                ...
# 4995  PVL02.001054/2021-13  Encaminhado à PGFN com manifestação técnica fa...
# 4996  PVL02.001443/2021-31                                  Deferido (PVL-IF)
# 4997  PVL02.002482/2021-55                                  Deferido (PVL-IF)
# 4998  PVL02.000401/2021-82                                           Deferido
# 4999  PVL02.000465/2022-64  Encaminhado à PGFN com manifestação técnica fa...
#
#               num_processo        data_protocolo  \
# 0     17944.001250/2011-71  2012-01-20T02:00:00Z
# 1     17944.001477/2012-05  2014-06-06T03:00:00Z
# 2     17944.001479/2009-91  2010-03-26T03:00:00Z
# 3     17944.001947/2014-94  2015-01-15T02:00:00Z
# 4     19406.000004/2003-12  2003-01-22T02:00:00Z
# ...                    ...                   ...
# 4995  17944.102234/2021-76  2021-11-08T17:18:16Z
# 4996                  None                  None
# 4997                  None                  None
# 4998  17944.103199/2021-11  2021-09-22T14:48:16Z
# 4999  17944.100521/2022-22  2022-05-03T19:01:13Z
#
#                                           tipo_operacao  \
# 0                           Operação contratual interna
# 1     Operação contratual externa (com garantia da U...
# 2     Operação contratual externa (com garantia da U...
# 3                           Operação contratual interna
# 4                           Operação contratual interna
# ...                                                 ...
# 4995  Operação contratual interna (com garantia da U...
# 4996                        Operação contratual interna
# 4997                        Operação contratual interna
# 4998                        Operação contratual interna
# 4999  Operação contratual interna (com garantia da U...
#
#                                              finalidade  \
# 0     PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 1                                        Multissetorial
# 2                                        Multissetorial
# 3     PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 4                                        Infraestrutura
# ...                                                 ...
# 4995                                     Infraestrutura
# 4996  Aquisição de terrenos, imóveis e/ou construção...
# 4997                                     Multissetorial
# 4998                                     Infraestrutura
# 4999                                     Infraestrutura
#
#                                tipo_credor  \
# 0          Instituição Financeira Nacional
# 1     Instituição Financeira Internacional
# 2     Instituição Financeira Internacional
# 3          Instituição Financeira Nacional
# 4          Instituição Financeira Nacional
# ...                                    ...
# 4995       Instituição Financeira Nacional
# 4996       Instituição Financeira Nacional
# 4997       Instituição Financeira Nacional
# 4998       Instituição Financeira Nacional
# 4999       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 0                               Caixa Econômica Federal           Real
# 1               Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2     Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 3                               Caixa Econômica Federal           Real
# 4     Agência de Fomento do Estado de Santa Catarina...           Real
# ...                                                 ...            ...
# 4995                            Caixa Econômica Federal           Real
# 4996                   Agência de Fomento do Paraná S/A           Real
# 4997       Banco de Desenvolvimento de Minas Gerais S/A           Real
# 4998                   Agência de Fomento do Paraná S/A           Real
# 4999                            Caixa Econômica Federal           Real
#
#             valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0       3660000.0                 0                      0  14/02/2012
# 1      50000000.0                 1                      0  01/07/2014
# 2     461000000.0                 1                      0  01/04/2010
# 3       1000000.0                 0                      0  28/01/2015
# 4        300000.0                 0                      0  20/02/2003
# ...           ...               ...                    ...         ...
# 4995    2000000.0                 0                      1  12/11/2021
# 4996    1000000.0                 0                      1  10/09/2021
# 4997     361800.0                 0                      1  28/09/2021
# 4998   40000000.0                 0                      1  23/09/2021
# 4999  100000000.0                 0                      1  10/05/2022
#
# [5000 rows x 18 columns]

# %%
# selecionando os valores referente aos municípios do estado do Rio de Janeiro
data_rj = data_br[data_br['uf'] == 'RJ']
data_rj
# Out:
#       id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 70         6797        Município   Rio de Janeiro   3304557  RJ
# 145        6266        Município           Maricá   3302700  RJ
# 230       13364           Estado   Rio de Janeiro        33  RJ
# 262       13036        Município          Niterói   3303302  RJ
# 300       12375           Estado   Rio de Janeiro        33  RJ
# ...         ...              ...              ...       ...  ..
# 4327      56075        Município          Resende   3304201  RJ
# 4391      38893        Município  Paty do Alferes   3303856  RJ
# 4723      27100        Município   Rio de Janeiro   3304557  RJ
# 4740      32249        Município        Queimados   3304144  RJ
# 4982      42252        Município         Itatiaia   3302254  RJ
#
#                    num_pvl                                             status  \
# 70                    None  Encaminhado à PGFN com manifestação técnica fa...
# 145                   None                                       Regularizado
# 230                   None  Encaminhado à PGFN com manifestação técnica fa...
# 262                   None                                       Regularizado
# 300                   None  Encaminhado à PGFN com manifestação técnica fa...
# ...                    ...                                                ...
# 4327  PVL02.003504/2022-85                                  Deferido (PVL-IF)
# 4391  PVL02.007600/2019-05                                  Deferido (PVL-IF)
# 4723  PVL02.002429/2017-78                     Arquivado por decurso de prazo
# 4740  PVL02.001397/2019-55           Em retificação pelo interessado (PVL-IF)
# 4982  PVL02.000042/2020-82  Encaminhado à PGFN com manifestação técnica fa...
#
#               num_processo        data_protocolo  \
# 70    17944.000432/2010-43  2010-07-01T03:00:00Z
# 145   17944.000308/2010-88  2011-12-19T02:00:00Z
# 230   17944.002059/2008-41  2009-05-14T03:00:00Z
# 262   17944.001891/2006-68  2006-12-30T02:00:00Z
# 300   17944.001671/2011-00  2011-10-18T02:00:00Z
# ...                    ...                   ...
# 4327                  None                  None
# 4391                  None                  None
# 4723  17944.103668/2017-15  2018-07-31T21:50:09Z
# 4740                  None                  None
# 4982  17944.101489/2020-31  2020-05-19T13:29:59Z
#
#                                           tipo_operacao  \
# 70    Operação contratual externa (com garantia da U...
# 145                         Operação contratual interna
# 230   Operação contratual externa (com garantia da U...
# 262                         Operação contratual interna
# 300   Operação contratual externa (com garantia da U...
# ...                                                 ...
# 4327                        Operação contratual interna
# 4391                        Operação contratual interna
# 4723                        Operação contratual interna
# 4740                        Operação contratual interna
# 4982  Operação contratual interna (com garantia da U...
#
#                                              finalidade  \
# 70    Reestruturação e recomposição do principal de ...
# 145          Regularização de Dívida - Energia Elétrica
# 230                                      Infraestrutura
# 262          Regularização de Dívida - Energia Elétrica
# 300                 Preservação e recuperação ambiental
# ...                                                 ...
# 4327     Aquisição de máquinas, equipamentos e veículos
# 4391     Aquisição de máquinas, equipamentos e veículos
# 4723                                     Infraestrutura
# 4740                                     Infraestrutura
# 4982                                     Infraestrutura
#
#                                tipo_credor  \
# 70    Instituição Financeira Internacional
# 145                    Empresa Não Estatal
# 230   Instituição Financeira Internacional
# 262                        Empresa Estatal
# 300   Instituição Financeira Internacional
# ...                                    ...
# 4327       Instituição Financeira Nacional
# 4391       Instituição Financeira Nacional
# 4723       Instituição Financeira Nacional
# 4740       Instituição Financeira Nacional
# 4982       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 70    Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 145                        Ampla Energia e Serviços S/A           Real
# 230   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 262         Companhia de Eletricidade do Rio de Janeiro           Real
# 300             Banco Interamericano de Desenvolvimento  Dólar dos EUA
# ...                                                 ...            ...
# 4327                                Banco do Brasil S/A           Real
# 4391     Agência de Fomento do Estado do Rio de Janeiro           Real
# 4723                            Caixa Econômica Federal           Real
# 4740                            Caixa Econômica Federal           Real
# 4982                                Banco do Brasil S/A           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 70    1.045000e+09                 1                      0  13/07/2010
# 145   8.623476e+05                 0                      0  20/01/2012
# 230   2.117000e+08                 1                      0  22/05/2009
# 262   4.146836e+06                 0                      0  12/01/2007
# 300   4.519800e+08                 1                      0  27/12/2011
# ...            ...               ...                    ...         ...
# 4327  2.160000e+06                 0                      1  28/07/2022
# 4391  3.512000e+06                 0                      1  30/10/2019
# 4723  1.000000e+08                 0                      0  07/01/2019
# 4740  5.000000e+06                 0                      0  06/09/2019
# 4982  3.000000e+07                 1                      1  21/05/2020
#
# [74 rows x 18 columns]

# %%
# 2) identificando os 3 status mais frequentes
status_tipos = data_rj['status'].unique()
status_tipos

status_qtd = data_rj['status'].value_counts()
status_qtd
# Out:
# Deferido                                                 25
# Encaminhado à PGFN com manifestação técnica favorável    17
# Arquivado                                                13
# Regularizado                                              5
# Arquivado por decurso de prazo                            5
# Deferido (PVL-IF)                                         4
# Em análise                                                2
# Assinado pelo interessado (retificação)                   1
# Arquivado a pedido                                        1
# Em retificação pelo interessado (PVL-IF)                  1
# Name: status, dtype: int64

# %%
# calculando a frequência
print(f'A frequencia do status "Deferido" é {round(25/74*100,2)}%')
print(f'A frequencia do status "Encaminhado à PGFN com manifestação técnica favorável" é {round(17/74*100,2)}%')
print(f'A frequencia do status "Arquivado" é {round(13/74*100,2)}%')
print(f'A frequencia do status "Regularizado" é {round(5/74*100,2)}%')
print(f'A frequencia do status "Arquivado por decurso de prazo" é {round(5/74*100,2)}%')
print(f'A frequencia do status "Deferido (PVL-IF)" é {round(4/74*100,2)}%')
print(f'A frequencia do status "Em análise" é {round(2/74*100,2)}%')
print(f'A frequencia do status "Assinado pelo interessado (retificação)" é {round(1/74*100,2)}%')
print(f'A frequencia do status "Arquivado a pedido" é {round(1/74*100,2)}%')
print(f'A frequencia do status "Em retificação pelo interessado (PVL-IF)" é {round(1/74*100,2)}%')
# Out:
# A frequencia do status "Deferido" é 33.78%
# A frequencia do status "Encaminhado à PGFN com manifestação técnica favorável" é 22.97%
# A frequencia do status "Arquivado" é 17.57%
# A frequencia do status "Regularizado" é 6.76%
# A frequencia do status "Arquivado por decurso de prazo" é 6.76%
# A frequencia do status "Deferido (PVL-IF)" é 5.41%
# A frequencia do status "Em análise" é 2.7%
# A frequencia do status "Assinado pelo interessado (retificação)" é 1.35%
# A frequencia do status "Arquivado a pedido" é 1.35%
# A frequencia do status "Em retificação pelo interessado (PVL-IF)" é 1.35%

# %%
data_br.head(2)
# Out:
#    id_pleito tipo_interessado        interessado  cod_ibge  uf num_pvl  \
# 0      10642        Município            Araricá   4300877  RS    None
# 1      11562           Estado  Rio Grande do Sul        43  RS    None
#
#                                               status          num_processo  \
# 0                     Arquivado por decurso de prazo  17944.001250/2011-71
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.001477/2012-05
#
#          data_protocolo                                      tipo_operacao  \
# 0  2012-01-20T02:00:00Z                        Operação contratual interna
# 1  2014-06-06T03:00:00Z  Operação contratual externa (com garantia da U...
#
#                                           finalidade  \
# 0  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 1                                     Multissetorial
#
#                             tipo_credor  \
# 0       Instituição Financeira Nacional
# 1  Instituição Financeira Internacional
#
#                                     credor          moeda       valor  \
# 0                  Caixa Econômica Federal           Real   3660000.0
# 1  Banco Interamericano de Desenvolvimento  Dólar dos EUA  50000000.0
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 0                      0  14/02/2012
# 1                 1                      0  01/07/2014

# %%
# 3) criar uma nova variável que contenha o ano do status
ano_status = data_rj['data_status'].apply(lambda x: x.split('/')[-1])
ano_status
# Out:
# 70      2010
# 145     2012
# 230     2009
# 262     2007
# 300     2011
#         ...
# 4327    2022
# 4391    2019
# 4723    2019
# 4740    2019
# 4982    2020
# Name: data_status, Length: 74, dtype: object

# %%
# 4) frequência do ano
ano_status.value_counts()
# Out:
# 2007    8
# 2008    8
# 2010    6
# 2019    6
# 2009    6
# 2011    6
# 2013    6
# 2014    6
# 2012    4
# 2023    3
# 2020    2
# 2002    2
# 2022    2
# 2015    2
# 2016    1
# 2017    1
# 2004    1
# 2006    1
# 2018    1
# 2021    1
# 2003    1
# Name: data_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
print('Digite a sigla do estado a ser consultado no banco de dados:\n')
# Out:
# Digite a sigla do estado a ser consultado no banco de dados:

# %%
# 2) Seu código aqui

# %%
# 3) Seu código aqui

# %%
# 4) Seu código aqui
